# %% [markdown]
# <a href="https://colab.research.google.com/github/CodewithSh9/CODETECHIT/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("/content/car_Dekho_DA_csv_shaped.csv")
data.head(15)
# Out:
#                      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0           Bajaj Avenger 220  2016           0.72           0.95         500
# 1                   Activa 3g  2016           0.45           0.54         500
# 2            Hero Passion Pro  2016           0.45           0.55        1000
# 3           Bajaj Dominar 400  2017           1.45           1.60        1200
# 4           Bajaj Avenger 220  2017           0.90           0.95        1300
# 5                   Activa 4g  2017           0.40           0.51        1300
# 6          UM Renegade Mojave  2017           1.70           1.82        1400
# 7           Suzuki Access 125  2008           0.25           0.58        1900
# 8               vitara brezza  2018           9.25           9.83        2071
# 9                    alto 800  2017           2.85           3.60        2135
# 10                      ignis  2017           4.90           5.71        2400
# ...

# %%
data.shape
# Out:
# (301, 10)

# %%
data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# difference       0
# dtype: int64

# %%
plt.boxplot(data['Kms_Driven'])
plt.show()

# %%
data.Kms_Driven.value_counts()
# Out:
# Kms_Driven
# 15000     9
# 45000     9
# 40000     5
# 25000     5
# 35000     5
#          ..
# 23709     1
# 24524     1
# 24678     1
# 24800     1
# 500000    1
# Name: count, Length: 206, dtype: int64

# %%
data.Present_Price.value_counts()
# Out:
# Present_Price
# 9.40     15
# 13.60    13
# 5.70      8
# 4.43      7
# 1.47      7
#          ..
# 7.90      1
# 5.59      1
# 2.40      1
# 0.88      1
# 23.73     1
# Name: count, Length: 147, dtype: int64

# %%
data=data[data['Present_Price']!='0.88']
data=data[data['Present_Price']!='1.47']
data=data[data['Present_Price']!='4.43']

# %%
data.shape
# Out:
# (301, 10)

# %%
X=data.drop(columns=['Seller_Type'])
Y=data['Seller_Type']
X
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0    Bajaj Avenger 220  2016           0.72           0.95         500
# 1            Activa 3g  2016           0.45           0.54         500
# 2     Hero Passion Pro  2016           0.45           0.55        1000
# 3    Bajaj Dominar 400  2017           1.45           1.60        1200
# 4    Bajaj Avenger 220  2017           0.90           0.95        1300
# ..                 ...   ...            ...            ...         ...
# 296            corolla  2004           1.50          12.35      135154
# 297              camry  2006           2.50          23.73      142000
# 298             innova  2005           3.49          13.46      197176
# 299      Honda Karizma  2010           0.31           1.05      213000
# 300          Activa 3g  2008           0.17           0.52      500000
#
#     Fuel_Type Transmission  Owner  difference
# 0      Petrol       Manual      0        0.23
# ...

# %%
plt.scatter(data['Selling_Price'],data['Present_Price'])
plt.xlabel('Selling_Price')
plt.ylabel('Present_Price')
# Out:
# Text(0, 0.5, 'Present_Price')

# %%
# %matplotlib inline

np.random.seed(42)
x = np.random.normal(size=1000)

plt.hist(x, density=True, bins=30)  # density=False would make counts
plt.ylabel('Present_Price')
plt.xlabel('Selling_Price');

# %%
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))

# plotting the heatmap
hm = sns.heatmap(data=data,
                annot=True)

# displaying the plotted heatmap
plt.show()
